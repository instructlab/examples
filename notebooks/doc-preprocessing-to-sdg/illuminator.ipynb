# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "93a65d7e",
   "metadata": {},
   "source": [
    "# Illuminator: Merged Cell Checker for Tables in PDFs\n",
    "\n",
    "Welcome to the Illuminator tool! This notebook guides you through analyzing PDF documents for problematic table structures, specifically **merged table cells**, using core functions from the Illuminator codebase.\n",
    "\n",
    "Note: This does not run a full Docling conversion — instead, it shows how to call and work with the functions used in the tool."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "cc217447",
   "metadata": {},
   "outputs": [],
   "source": [
    "from analysis import summarize_tables, analyze_pdf_with_docling\n",
    "from utils import format_pages, generate_summary\n",
    "from pathlib import Path\n",
    "import json"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "fb4bec7c",
   "metadata": {},
   "source": [
    "## Step 1: Set Your PDF Path"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "c26b2be3",
   "metadata": {},
   "outputs": [],
   "source": [
    "pdf_path = Path(\"/path/to/your/file.pdf\")  # Replace with your PDF file path"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "015782ef",
   "metadata": {},
   "source": [
    "## Step 2: Analyze the PDF and View Raw Results"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "9cebd5b5",
   "metadata": {},
   "outputs": [],
   "source": [
    "results = analyze_pdf_with_docling(str(pdf_path))\n",
    "results"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "5f3663be",
   "metadata": {},
   "source": [
    "## Step 3: Print Summary Report"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "c3eca769",
   "metadata": {},
   "outputs": [],
   "source": [
    "generate_summary({str(pdf_path): results})"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "9cec2131",
   "metadata": {},
   "source": [
    "## Step 4: Format Pages with Merged Table Cells"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "9a0450cb",
   "metadata": {},
   "outputs": [],
   "source": [
    "format_pages(results['merged_cell_pages'])"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "6812aa0f",
   "metadata": {},
   "source": [
    "## Step 5: Export Results as JSON"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "392b8e58",
   "metadata": {},
   "outputs": [],
   "source": [
    "with open(\"results.json\", \"w\") as f:\n",
    "    json.dump({str(pdf_path): results}, f, indent=4)\n",
    "print(\"Results saved to results.json\")"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 5
}
